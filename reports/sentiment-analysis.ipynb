# %%
import os
os.listdir()
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as pyp

pd.set_option('max_columns', 50)
#Inline imaging
# %matplotlib inline
df = pd.read_csv('sentiment_analysis.csv', delimiter='|')
#df.set_index('issue_number', inplace=True)
df.head(1)
# Out:
#                                              comment          author  \
# 0  Would it be clearer or less clear to make this...  David Ginsburg
#
#    overall_positivity  number classified_as
# 0            0.828821    3386           pos

# %%
data = df[(df['overall_positivity'] > 0.50)]

# %%
data.head(2)
# Out:
#                                              comment          author  \
# 0  Would it be clearer or less clear to make this...  David Ginsburg
# 1  > Team or User Account should be the organizat...  David Ginsburg
#
#    overall_positivity  number classified_as
# 0            0.828821    3386           pos
# 1            0.604472    3381           pos

# %%
plot = [data.index, data['overall_positivity']]
jp = sns.jointplot(x=data.index, y=(comm_nums['overall_positivity']), kind="reg", ylim=(0.5, 1), size=20, color="g")
jp.savefig('sentiment_regression')
